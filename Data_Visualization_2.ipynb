# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns
from numpy.random import randn, randint, uniform, sample

# %%
x = [1,2,3,4,5,6,7,8,9]
y1 = [1, 3, 5, 3, 1, 3, 5, 3, 1]
y2 = [2, 4, 6, 4, 2, 4, 6, 4, 2]
plt.plot(x, y1, label="line L")
plt.plot(x, y2, label="line H")
plt.plot()

plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Line Graph")
plt.legend()
plt.show()

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %% [markdown]
# # Bar Chart

# %%
x = [2,8,10] 
y = [11,16,9]  

x2 = [3,9,11] 
y2 = [6,15,7] 

plt.bar(x,y,label = 'x-y variation')  # plt.barh()...horizontal
plt.bar(x2,y2,color = 'g', label = "x2-y2")
plt.title('Bar graph')
plt.xlabel('X axis') # ylabel 
plt.ylabel('Y axis')  #xlabel 
plt.legend()
plt.show()

#2->11,8->16 etc(comparison )

# %%
x1 = [1, 3, 4, 5, 6, 7, 9]
y1 = [4, 7, 2, 4, 7, 8, 3]

x2 = [2, 4, 6, 8, 10]
y2 = [5, 6, 2, 6, 2]

# Colors: https://matplotlib.org/api/colors_api.html

plt.bar(x1, y1, label="Blue Bar", color='b')
plt.bar(x2, y2, label="Green Bar", color='g')
plt.plot()

plt.xlabel("bar number")
plt.ylabel("bar height")
plt.title("Bar Chart Example")
plt.legend()
plt.show()

# %%
## Create a dataframe with 10rows on random numbers and 4 columns, (columns labelled as a,b,c,d) and plot a bar chart.
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.196639  0.107784 -0.203167  0.255187
# 1 -1.212738  0.341378 -0.165413 -1.786295
# 2 -0.517913  0.938243  0.092920  1.357008
# 3  0.086236 -0.892263  0.148152 -0.504533
# 4  0.552913  0.102906 -0.039590  1.507125
# 5  1.056074 -0.261839 -2.007164  0.786115
# 6 -0.074242 -0.795960  0.503090 -0.279493
# 7 -1.041111 -0.004254 -0.308193  0.023533
# 8 -0.148411 -1.541431 -0.388351  0.712251
# 9 -0.472279  0.722502  0.375435 -0.665493

# %%
df.plot.bar()
plt.show()

# %%
df.plot.bar(stacked = True)

# %%
df.plot.barh(stacked = True)

# %% [markdown]
# # Histograms
#
# Histograms are likely familiar, and a hist function already exists in matplotlib. A histogram represents the distribution of data by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.
#
# To illustrate this, let’s remove the density curve and add a rug plot, which draws a small vertical tick at each observation. You can make the rug plot itself with the rugplot() function, but it is also available in distplot():

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27,9])
plt.hist(a)
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
iris = sns.load_dataset('iris')
iris.head(10)#default 5
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris['sepal_length'].plot.hist() #hist showcases distributn in x-axis and magnitude in y-axis

# %%
iris.plot.hist() ### iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = False, bins = 10)

# %%
iris.plot(kind = 'hist',stacked = True, bins = 20)

# %%
iris['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
#iris['sepal_width'].diff().plot.hist()
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 20)

# %%
df = iris.drop(['species'],axis = 1)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.hist(color = '#FF33F4', alpha = 0.9, figsize=(10,10)) #df.plot.hist() gives single plot// alpha = color intensity
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f226e018190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f226e068c90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f226dfe5310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f226df99b10>]],
#       dtype=object)

# %% [markdown]
# # Pie chart

# %%
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0.1, 0.1, 0.1)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.2f%%', shadow=False)# auto= decimal point

plt.axis('equal')
plt.show()

# %%
series = pd.Series([0.2]*5)
series
# Out:
# 0    0.2
# 1    0.2
# 2    0.2
# 3    0.2
# 4    0.2
# dtype: float64

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %% [markdown]
# # Scatter plot
#
# The most familiar way to visualize a bivariate distribution is a scatterplot, where each observation is shown with point at the x and y values.

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2021-07-01', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2021-07-01', periods = 1000))
df.head()
# Out:
#                value
# 2021-07-01 -0.746726
# 2021-07-02 -0.539248
# 2021-07-03  1.770832
# 2021-07-04 -0.701014
# 2021-07-05 -0.794691

# %%
ts.plot.kde()

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)
